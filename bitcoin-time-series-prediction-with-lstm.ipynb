# %% [markdown]
# ## Import necessary libraries

# %%
# handling the data
import numpy as np
import systemcheck
import pandas as pd
from math import sqrt
from numpy import concatenate
from datetime import datetime

# transformation of the data
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# model evaluation
from sklearn.metrics import mean_squared_error

# for data visualization
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
from matplotlib import pyplot as plt
py.init_notebook_mode(connected=True)
# %matplotlib inline

# for creating and training RNN(LSTM)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
# Out:
# C:\Users\vishnu\Desktop\bit coin price prediction
# everything is checked.. system okay
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Loading dataset

# %%
data = pd.read_csv(r"data.csv", index_col="Date")
data
# Out:
#                   Open        High         Low       Close  Volume (BTC)  \
# Date
# 2014-01-07   874.67040   892.06753   810.00000   810.00000     15.622378
# 2014-01-08   810.00000   899.84281   788.00000   824.98287     19.182756
# 2014-01-09   825.56345   870.00000   807.42084   841.86934      8.158335
# 2014-01-10   839.99000   857.34056   817.00000   857.33056      8.024510
# 2014-01-11   858.20000   918.05471   857.16554   899.84105     18.748285
# ...                ...         ...         ...         ...           ...
# 2017-10-13  5429.80000  5854.40000  5380.10000  5640.00000   9222.144339
# 2017-10-14  5626.70000  5800.00000  5556.10000  5800.00000   3019.946476
# 2017-10-15  5800.00000  5840.40000  5462.10000  5680.00000   4536.386215
# 2017-10-16  5673.20000  5776.60000  5550.00000  5738.80000   3134.620657
# 2017-10-17  5738.70000  5759.90000  5535.10000  5577.80000   3322.439554
#
#             Volume (Currency)  Weighted Price
# Date
# 2014-01-07       1.315147e+04      841.835522
# 2014-01-08       1.609733e+04      839.156269
# 2014-01-09       6.784250e+03      831.572913
# 2014-01-10       6.780220e+03      844.938794
# 2014-01-11       1.669857e+04      890.671709
# ...                       ...             ...
# 2017-10-13       5.178706e+07     5615.511555
# 2017-10-14       1.719205e+07     5692.831135
# 2017-10-15       2.545265e+07     5610.777658
# 2017-10-16       1.778638e+07     5674.172630
# 2017-10-17       1.869327e+07     5626.368279
#
# [1380 rows x 7 columns]

# %% [markdown]
# ## data analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1380 entries, 2014-01-07 to 2017-10-17
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Open               1380 non-null   float64
#  1   High               1380 non-null   float64
#  2   Low                1380 non-null   float64
#  3   Close              1380 non-null   float64
#  4   Volume (BTC)       1380 non-null   float64
#  5   Volume (Currency)  1380 non-null   float64
#  6   Weighted Price     1380 non-null   float64
# dtypes: float64(7)
# memory usage: 86.2+ KB

# %%
btc_WP = go.Scatter(x=data.index, y=data['Weighted Price'], name= 'Price')
py.iplot([btc_WP])
# Out:
# <div>                            <div id="5871b05a-9c3c-4214-ba94-ea37ff17f55b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5871b05a-9c3c-4214-ba94-ea37ff17f55b")) {                    Plotly.newPlot(                        "5871b05a-9c3c-4214-ba94-ea37ff17f55b",                        [{"name": "Price", "type": "scatter", "x": ["2014-01-07", "2014-01-08", "2014-01-09", "2014-01-10", "2014-01-11", "2014-01-12", "2014-01-13", "2014-01-14", "2014-01-15", "2014-01-16", "2014-01-17", "2014-01-18", "2014-01-19", "2014-01-20", "2014-01-21", "2014-01-22", "2014-01-23", "2014-01-24", "2014-01-25", "2014-01-26", "2014-01-27", "2014-01-28", "2014-01-29", "2014-01-30", "2014-01-31", "2014-02-01", "2014-02-02", "2014-02-03", "2014-02-04", "2014-02-05", "2014-02-06", "2014-02-07", "2014-02-08", "2014-02-09", "2014-02-10", "2014-02-11", "2014-02-12", "2014-02-13", "2014-02-14", "2014-02
"2014-07-07", "2014-07-08", "2014-07-09", "2014-07-10", "2014-07-11", "2014-07-12", "2014-07-13", "2014-07-14", "2014-07-15", "2014-07-16", "2014-07-17", "2014-07-18", "2014-07-19", "2014-07-20", "2014-07-21", "2014-07-22", "2014-07-23", "2014-07-24", "2014-07-25", "2014-07-26", "2014-07-27", "2014-07-28", "2014-07-29", "2014-07-30", "2014-07-31", "2014-08-01", "2014-08-02", "2014-08-03", "2014-08-04", "2014-08-05", "2014-08-06", "2014-08-07", "2014-08-08", "2014-08-09", "2014-08-10", "2014-08-11", "2014-08-12", "2014-08-13", "2014-08-14", "2014-08-15", "2014-08-16", "2014-08-17", "2014-08-18", "2014-08-19", "2014-08-20", "2014-08-21", "2014-08-22", "2014-08-23", "2014-08-24", "2014-08-25", "2014-08-26", "2014-08-27", "2014-08-28", "2014-08-29", "2014-08-30", "2014-08-31", "2014-09-01", "2014-09-02", "2014-09-03", "2014-09-04", "2014-09-05", "2014-09-06", "2014-09-07", "2014-09-0 ...

# %% [markdown]
# ### Using `Weighted Price` as a feature to train the LSTM model

# %% [markdown]
# #### Use MinMaxScaler to normalize `Weighted Price` to range from 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler
values = data['Weighted Price'].values.reshape(-1,1)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %% [markdown]
# ## Split the data 70% for training and 30% for testing

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
print("train shape: ",train.shape,"\n","test shape: ",test.shape)
# Out:
# train shape:  (965, 1)
#  test shape:  (415, 1)

# %% [markdown]
# #### Create function for creating dataset with look back

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #### Generate dataset for trainX, trainY, testX, testY

# %%
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# Out:
# 960
# 410

# %%
trainX[:5]
# Out:
# array([[0.11690941, 0.11642168, 0.11504118, 0.11747435, 0.12579972],
#        [0.11642168, 0.11504118, 0.11747435, 0.12579972, 0.12029894],
#        [0.11504118, 0.11747435, 0.12579972, 0.12029894, 0.11516626],
#        [0.11747435, 0.12579972, 0.12029894, 0.11516626, 0.11749206],
#        [0.12579972, 0.12029894, 0.11516626, 0.11749206, 0.11830641]],
#       dtype=float32)

# %%
trainY[:5]
# Out:
# array([0.12029894, 0.11516626, 0.11749206, 0.11830641, 0.11787233],
#       dtype=float32)

# %% [markdown]
# #### Reshape X for model training

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
print("train shape: ",trainX.shape,"\n","test shape: ",testX.shape)
# Out:
# train shape:  (960, 1, 5)
#  test shape:  (410, 1, 5)

# %% [markdown]
# #### Creating and training the LSTM model

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=100, batch_size=100, validation_data=(testX, testY), verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 3s 76ms/step - loss: 0.0318 - val_loss: 0.2484
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0223 - val_loss: 0.2021
# Epoch 3/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0203 - val_loss: 0.1767
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0171 - val_loss: 0.1633
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0151 - val_loss: 0.1414
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0134 - val_loss: 0.1140
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0114 - val_loss: 0.0890
# Epoch 8/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0092 - val_loss: 0.0634
# Epoch 9/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0352
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0205
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0314
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0354
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0238
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0211
# Epoch 15/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0250
# Epoch 16/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0303
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0238
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0210
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0239
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0286
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0221
# Epoch 22/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0211
# Epoch 23/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0238
# Epoch 24/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0284
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0213
# Epoch 26/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0212
# Epoch 27/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0233
# Epoch 28/100
# 10/10 [==============================] - ETA: 0s - loss: 0.004 - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0276
# Epoch 29/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.0205
# Epoch 30/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0215
# Epoch 31/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0220
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0265
# Epoch 33/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0201
# Epoch 34/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0209
# Epoch 35/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0217
# Epoch 36/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0261
# Epoch 37/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0192
# Epoch 38/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0210
# Epoch 39/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0214
# Epoch 40/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0260
# Epoch 41/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0188
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0214
# Epoch 43/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0204
# Epoch 44/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0246
# Epoch 45/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0183
# Epoch 46/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0212
# Epoch 47/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0198
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0238
# Epoch 49/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0177
# Epoch 50/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0213
# Epoch 51/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 0.0193
# Epoch 52/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0233
# Epoch 53/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0172
# Epoch 54/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0214
# Epoch 55/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0187
# Epoch 56/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0226
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0168
# Epoch 58/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0213
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0183
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0220
# Epoch 61/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0163
# Epoch 62/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0214
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0179
# Epoch 64/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0214
# Epoch 65/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0159
# Epoch 66/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0220
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0172
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0206
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0157
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0215
# Epoch 71/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0034 - val_loss: 0.0169
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0201
# Epoch 73/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0152
# Epoch 74/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0219
# Epoch 75/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0165
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0197
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0150
# Epoch 78/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0219
# Epoch 79/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0161
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0191
# Epoch 81/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0147
# Epoch 82/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0217
# Epoch 83/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0160
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0185
# Epoch 85/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0145
# Epoch 86/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.0221
# Epoch 87/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0156
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0183
# Epoch 89/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0143
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0229
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0151
# Epoch 92/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0175
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0142
# Epoch 94/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0225
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0149
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0171
# Epoch 97/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 98/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0227
# Epoch 99/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0147
# Epoch 100/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0171

# %% [markdown]
# #### Plot line graph to show amount loss according the the epoch

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# #### Make prediction using textX and plotting line graph against testY

# %%
y_p1 = model.predict(testX)
plt.plot(y_p1, label='predict')
plt.plot(testY, label='true')
plt.legend()
plt.show()

# %% [markdown]
# #### Scaler Inverse Y back to normal value

# %%
y_p_inverse = scaler.inverse_transform(y_p1.reshape(-1, 1))
testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))

# %% [markdown]
# #### evaluation

# %%
rmse = sqrt(mean_squared_error(testY_inverse, y_p_inverse))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 168.399

# %% [markdown]
# #### Plot line graph with Y as USD

# %%
plt.plot(y_p_inverse, label='predict')
plt.plot(testY_inverse, label='actual', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# #### Convert X to dates

# %%
predictDates = data.tail(len(testX)).index

# %% [markdown]
# #### Reshape testY and y_pred for plotly

# %%
testY_reshape = testY_inverse.reshape(len(testY_inverse))
yhat_reshape = y_p_inverse.reshape(len(y_p_inverse))

# %% [markdown]
# #### Plot predicted and actual line graph with X=dates, Y=USD

# %%
actual_chart = go.Scatter(x=predictDates, y=testY_reshape, name= 'Actual Price')
predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, name= 'Predict Price')
py.iplot([predict_chart, actual_chart])
# Out:
# <div>                            <div id="415d433f-4418-49bd-873f-a8592138bd63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("415d433f-4418-49bd-873f-a8592138bd63")) {                    Plotly.newPlot(                        "415d433f-4418-49bd-873f-a8592138bd63",                        [{"name": "Predict Price", "type": "scatter", "x": ["2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2 ...

# %% [markdown]
# # Second-Model: Using additional features for model training

# %% [markdown]
# #### Find corrleration in features to `Weighted Price`

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.1, vmin=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation: `Volume` is corrlerated to `Weighted Price`.
# `Open`, `High`, `Low`, `Close` are directly related to `Weighted Price`

# %% [markdown]
# #### Function to convert series to supervised learning

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# #### Get all data values

# %%
values = data[['Weighted Price'] + ['Volume (BTC)'] + ['Volume (Currency)']].values
values = values.astype('float32')
values[:5]
# Out:
# array([[8.4183551e+02, 1.5622378e+01, 1.3151473e+04],
#        [8.3915625e+02, 1.9182756e+01, 1.6097329e+04],
#        [8.3157294e+02, 8.1583347e+00, 6.7842500e+03],
#        [8.4493878e+02, 8.0245104e+00, 6.7802202e+03],
#        [8.9067169e+02, 1.8748285e+01, 1.6698566e+04]], dtype=float32)

# %% [markdown]
# #### Normalize features to range from 0 to 1

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %% [markdown]
# #### Frame as supervised learning

# %%
reframed = series_to_supervised(scaled, 1, 1)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)   var2(t)   var3(t)
# 1   0.116909   0.000715   0.000177  0.116422  0.000878  0.000216
# 2   0.116422   0.000878   0.000216  0.115041  0.000373  0.000091
# 3   0.115041   0.000373   0.000091  0.117474  0.000367  0.000091
# 4   0.117474   0.000367   0.000091  0.125800  0.000858  0.000225
# 5   0.125800   0.000858   0.000225  0.120299  0.001164  0.000294

# %% [markdown]
# #### Drop unncessary columns

# %%
reframed.drop(reframed.columns[[4,5]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)
# 1   0.116909   0.000715   0.000177  0.116422
# 2   0.116422   0.000878   0.000216  0.115041
# 3   0.115041   0.000373   0.000091  0.117474
# 4   0.117474   0.000367   0.000091  0.125800
# 5   0.125800   0.000858   0.000225  0.120299

# %% [markdown]
# #### Split data to 70% training, 30% testing

# %%
values = reframed.values
n_train_hours = int(len(values) * 0.7)
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (965, 1, 3) (965,) (414, 1, 3) (414,)

# %% [markdown]
# ## Training the LSTM model-2

# %%
multi_model = Sequential()
multi_model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
multi_model.add(Dense(1))
multi_model.compile(loss='mae', optimizer='adam')
multi_history = multi_model.fit(train_X, train_y, epochs=100, batch_size=100, validation_data=(test_X, test_y), verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 4s 73ms/step - loss: 0.0298 - val_loss: 0.2380
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0231 - val_loss: 0.2135
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0223 - val_loss: 0.2025
# Epoch 4/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0208 - val_loss: 0.1980
# Epoch 5/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0200 - val_loss: 0.1904
# Epoch 6/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0198 - val_loss: 0.1803
# Epoch 7/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0190 - val_loss: 0.1711
# Epoch 8/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0187 - val_loss: 0.1622
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0179 - val_loss: 0.1541
# Epoch 10/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0175 - val_loss: 0.1436
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0171 - val_loss: 0.1355
# Epoch 12/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0162 - val_loss: 0.1289
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0160 - val_loss: 0.1190
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.1111
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.1043
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - val_loss: 0.0974
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0137 - val_loss: 0.0899
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0130 - val_loss: 0.0825
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - val_loss: 0.0752
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - val_loss: 0.0678
# Epoch 21/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0599
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0513
# Epoch 23/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0428
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0338
# Epoch 25/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0075 - val_loss: 0.0258
# Epoch 26/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0197
# Epoch 27/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0179
# Epoch 28/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0228
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0312
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0393
# Epoch 31/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0386
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0337
# Epoch 33/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0204
# Epoch 34/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0198
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0309
# Epoch 36/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0388
# Epoch 37/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0040 - val_loss: 0.0425
# Epoch 38/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0274
# Epoch 39/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0187
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0256
# Epoch 41/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0356
# Epoch 42/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0339
# Epoch 43/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0030 - val_loss: 0.0260
# Epoch 44/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0158
# Epoch 45/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0163
# Epoch 46/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0254
# Epoch 47/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0347
# Epoch 48/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0347
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0302
# Epoch 50/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0216
# Epoch 51/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 52/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0045 - val_loss: 0.0158
# Epoch 53/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0258
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0356
# Epoch 55/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0336
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0316
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0195
# Epoch 58/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0158
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0193
# Epoch 60/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0305
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0306
# Epoch 62/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0282
# Epoch 63/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0230
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0145
# Epoch 65/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0150
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0029 - val_loss: 0.0212
# Epoch 67/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0327
# Epoch 68/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0334
# Epoch 69/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0317
# Epoch 70/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0164
# Epoch 71/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0152
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0206
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0306
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0297
# Epoch 75/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0237
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0137
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0143
# Epoch 78/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0207
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0294
# Epoch 80/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0286
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0277
# Epoch 82/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0197
# Epoch 83/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0127
# Epoch 84/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0139
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0201
# Epoch 86/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0304
# Epoch 87/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0334
# Epoch 88/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0235
# Epoch 89/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 90/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0153
# Epoch 91/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0163
# Epoch 92/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0255
# Epoch 93/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0265
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0253
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0195
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0122
# Epoch 97/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0136
# Epoch 98/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0182
# Epoch 99/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0287
# Epoch 100/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0320

# %% [markdown]
# #### Plot line graph to show amount loss according the the epoch

# %%
plt.plot(multi_history.history['loss'], label='multi_train')
plt.plot(multi_history.history['val_loss'], label='multi_test')
plt.legend()
plt.show()

# %% [markdown]
# #### Make prediction using textX and plotting line graph against testY

# %%
yhat = multi_model.predict(test_X)
plt.plot(yhat, label='predict')
plt.plot(test_y, label='true')
plt.legend()
plt.show()

# %% [markdown]
# #### Scaler Inverse Y back to normal value

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %% [markdown]
# #### RMSE

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: